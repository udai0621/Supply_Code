# %%
from Output_dir import Output

# %%
# ディレクトリ指定
directory = './test/'

# %%
output = Output(directory = directory)

# %%
output.result(csv = True)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
#          age gender  emotion             race
# img1.jpg  31  Woman    happy  latino hispanic
# img2.jpg  31  Woman  neutral            white
# img3.jpg  28  Woman    happy            white
# img4.jpg  31  Woman    happy            white
# img5.jpg  30  Woman  neutral            white
