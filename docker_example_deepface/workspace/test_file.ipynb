# %%
from Output import Output

# %%
# パス指定
img_path = './data/uchiba.png'

# %%
output = Output(img_path = img_path)

# %%
output.result()
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.70it/s]
#            age gender emotion   race
# uchiba.png  24    Man   happy  asian

# %%
output.to_csv()
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.30it/s]
